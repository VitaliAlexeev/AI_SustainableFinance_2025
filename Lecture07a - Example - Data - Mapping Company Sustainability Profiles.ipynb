# %% [markdown]
# # Mapping Sustainability Data

# %%
#!pip install geopy
#!pip install folium

# %% [markdown]
# ## Python Packages for Geospatial Analysis and Mapping
#
# ### `geopy`
#
# The **`geopy`** package in Python provides tools for **geocoding** (finding latitude and longitude from an address) and **reverse geocoding** (finding an address from latitude and longitude). It acts as a wrapper around popular geocoding web services such as Google Maps, OpenStreetMap (Nominatim), Bing Maps, and others.
#
# Key functionalities include:
# - Converting street addresses into geographic coordinates.
# - Converting geographic coordinates into addresses.
# - Calculating distances between points using different methods (great-circle, Vincenty, etc.).
#
# **Example uses**:
# - Find the coordinates of `"Sydney Opera House"`.
# - Calculate the distance between Sydney and Melbourne.
#
#
# ### `folium`
#
# The **`folium`** package allows you to **create interactive maps** in Python, built on top of the JavaScript library **Leaflet.js**. It is particularly useful for data visualisation when working with geographic data.
#
# Key functionalities include:
# - Displaying maps centred at specific coordinates.
# - Adding markers, popups, and circles to maps.
# - Overlaying choropleth maps and heatmaps.
# - Saving interactive maps as HTML files to share or embed.
#
# **Example uses**:
# - Create a choropleth map of world population.
# - Visualise geospatial data interactively inside a Jupyter Notebook.
#
#
# **Summary**
#
# - **`geopy`** → focuses on **geocoding** and **distance calculations**.
# - **`folium`** → focuses on **visualisation** and **interactive maps**.
#
# These two packages are often used **together**:
# 1. Use `geopy` to obtain coordinates.
# 2. Use `folium` to plot those coordinates on an interactive map.

# %%
import yfinance as yf
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.distance import geodesic
import folium   # library to plot the coordinates on an interactive map
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Getting coordinates
#
# Getting Company Headquarters Coordinates: You can use the `geopy` library to get the coordinates of company headquarters based on the location information provided by **Yahoo Finance**. The info object from Yahoo Finance often contains a 'city' and 'country' key, which you can use to determine the coordinates using a geocoding API like OpenStreetMap's Nominatim.
#
# Try it in a simple code example below:

# %%
geolocator = Nominatim(user_agent="company_locator")
location=geolocator.geocode("Sydney, Australia")
lat = location.latitude
lon = location.longitude
print(f"Latitude: {lat}; Longitude: {lon}")
# Out:
# Latitude: -33.8698439; Longitude: 151.2082848

# %% [markdown]
# ## Calculating distances

# %%
# Get coordinates for Sydney and Melbourne
sydney_location = geolocator.geocode("Sydney, Australia")
melbourne_location = geolocator.geocode("Melbourne, Australia")

print("Sydney:", (sydney_location.latitude, sydney_location.longitude))
print("Melbourne:", (melbourne_location.latitude, melbourne_location.longitude))

# Calculate distance
sydney_coords = (sydney_location.latitude, sydney_location.longitude)
melbourne_coords = (melbourne_location.latitude, melbourne_location.longitude)

distance_km = geodesic(sydney_coords, melbourne_coords).kilometers
print(f"Distance between Sydney and Melbourne: {distance_km:.2f} km")
# Out:
# Sydney: (-33.8698439, 151.2082848)
# Melbourne: (-37.8142454, 144.9631732)
# Distance between Sydney and Melbourne: 713.75 km

# %% [markdown]
# ## Select the companies for analysis

# %%
# Option A: Specify a list of tickers:
tickers = ['DELL', 'ABNB', 'PANW', 'BKNG', 'UBER', 'IBM', 'SCCO', 'ADBE',
          'NFLX', 'SAP', 'TXN', 'ORCL', 'TTD', 'MU', 'PYPL', 'INTC',
          'GOOG', 'MSFT', 'NVDA', 'AMZN', 'META', 'TSLA', 'AAPL', 'AMD', 'CRM',
          'BA', 'AA', 'MMM', 'AMGN', 'CAT', 'CVX', 'CSCO', 'KO', 'DOW', 'DIS']

# %%
# Option B: Specify a list of tickers:
# Open the file in read mode
#with open('data/stock_symbol_list_SP500_B.txt', 'r') as file:
#    # Read each line and strip any leading/trailing whitespace characters (like newlines)
#    tickers = [line.strip() for line in file]

# %% [markdown]
# ## Download company data

# %%
# Initialize an empty list to store data
data = []

# Initialize geolocator
geolocator = Nominatim(user_agent="company_locator")

# %%
# Loop through each ticker and extract the required information
for ticker in tickers:
    stock = yf.Ticker(ticker)
   
    print(ticker)
    
    # Initialize ESG scores to None by default
    environment_score = social_score = governance_score = None
    city = country = None
    lat = lon = None
    
    try:
        # Extract the sustainability scores 
        sustainability = stock.sustainability
        
        # If sustainability data is available, extract the relevant ESG scores
        environment_score = sustainability.loc['environmentScore'].values[0]
        social_score = sustainability.loc['socialScore'].values[0]
        governance_score = sustainability.loc['governanceScore'].values[0]
    except KeyError:
        # If the ESG scores are not available, they remain as None
        print(f"Sustainability data is currently not available for {ticker}.")
        
    # Extract other relevant information
    info = stock.info
    market_cap = info.get('marketCap')
    industry_sector = info.get('sector')
    city = info.get('city')
    country = info.get('country')
    
    # Get coordinates using the city and country
    if city and country:
        location = geolocator.geocode(f"{city}, {country}")
        if location:
            lat = location.latitude
            lon = location.longitude
        else:
            print(f"Coordinates not found for {ticker} in {city}, {country}")
    
    # Append the data to the list
    data.append([ticker, environment_score, social_score, governance_score, market_cap, industry_sector, city, country, lat, lon])

# Convert the list to a pandas DataFrame
df = pd.DataFrame(data, columns=['Ticker', 'Environment Score', 'Social Score', 'Governance Score', 'Market Cap', 'Industry Sector', 'City', 'Country', 'Latitude', 'Longitude'])
# Out:
# DELL
# ABNB
# PANW
# BKNG
# UBER
# IBM
# SCCO
# ADBE
# NFLX
# SAP
# HTTP Error 404:
# Sustainability data is currently not available for SAP.
# TXN
# ORCL
# TTD
# MU
# PYPL
# INTC
# GOOG
# HTTP Error 404:
# Sustainability data is currently not available for GOOG.
# MSFT
# NVDA
# AMZN
# META
# TSLA
# AAPL
# AMD
# CRM
# BA
# AA
# MMM
# AMGN
# CAT
# CVX
# CSCO
# KO
# DOW
# DIS

# %%
# Display the DataFrame
df
# Out:
#    Ticker  Environment Score  Social Score  Governance Score     Market Cap  \
# 0    DELL               2.31          7.00              4.56    84432764928
# 1    ABNB               0.88          9.83              6.68    75800944640
# 2    PANW               0.05          7.99              4.89   130074296320
# 3    BKNG               0.87          9.55              4.02   178442420224
# 4    UBER               3.74         12.16              5.81   189752360960
# 5     IBM               1.58          6.68              5.01   231510409216
# 6    SCCO              11.89          7.76              5.91    83639222272
# 7    ADBE               2.78          6.75              4.71   148033077248
# 8    NFLX               0.16          7.38              8.35   528531456000
# 9     SAP                NaN           NaN               NaN   313430736896
# 10    TXN              10.42          4.79              4.92   170854121472
# 11   ORCL               1.58          6.49              6.57   653895598080
# 12    TTD               1.33         13.26              7.60    25459261440
# 13     MU               8.88          5.03              4.89   147020103680
# 14   PYPL               4.26         10.65              4.08    65214103552
# 15   INTC               7.56          6.86              4.39   107717304320
# 16   GOOG                NaN           NaN               NaN  2841723535360
# 17   MSFT               3.68          8.42              4.80  3775825444864
# 18   NVDA               2.81          3.64              5.65  4179408453632
# 19   AMZN               8.19         10.77              6.75  2477776175104
# 20   META               2.47         21.64              8.68  1890259828736
# 21   TSLA               3.04         14.13              7.60  1131616796672
# 22   AAPL               2.33          7.98              8.58  3557095374848
# 23    AMD               3.01          4.22              5.28   262560399360
# 24    CRM               4.06         10.33              4.09   238723514368
# 25     BA              11.22         20.69              6.53   173621444608
# 26     AA              14.95          8.90              3.55     8241264640
# 27    MMM              19.95         16.82              7.47    82834538496
# 28   AMGN               1.65         14.65              6.05   152700993536
# 29    CAT              10.17         11.77              6.39   198204096512
# 30    CVX              19.00          9.60              7.46   309597241344
# 31   CSCO               0.40          7.49              5.05   264469102592
# 32     KO              12.73         10.62              4.96   292477403136
# 33    DOW              14.65          4.08              3.63    17366679552
# 34    DIS               0.10          9.97              5.93   211993935872
#
#            Industry Sector           City        Country   Latitude  \
# 0               Technology     Round Rock  United States  30.508592
# 1        Consumer Cyclical  San Francisco  United States  37.779259
# 2               Technology    Santa Clara  United States  37.354113
# 3        Consumer Cyclical        Norwalk  United States  41.117597
# 4               Technology  San Francisco  United States  37.779259
# 5               Technology         Armonk  United States  41.132973
# 6          Basic Materials        Phoenix  United States  33.448437
# 7               Technology       San Jose  United States  37.336166
# 8   Communication Services      Los Gatos  United States  37.226611
# 9               Technology       Walldorf        Germany  49.303813
# 10              Technology         Dallas  United States  32.776272
# 11              Technology         Austin  United States  30.271129
# 12  Communication Services        Ventura  United States  34.445825
# 13              Technology          Boise  United States  43.616616
# 14      Financial Services       San Jose  United States  37.336166
# 15              Technology    Santa Clara  United States  37.354113
# 16  Communication Services  Mountain View  United States  37.389389
# 17              Technology        Redmond  United States  47.669414
# 18              Technology    Santa Clara  United States  37.354113
# 19       Consumer Cyclical        Seattle  United States  47.603832
# 20  Communication Services     Menlo Park  United States  37.451967
# 21       Consumer Cyclical         Austin  United States  30.271129
# 22              Technology      Cupertino  United States  37.322893
# 23              Technology    Santa Clara  United States  37.354113
# 24              Technology  San Francisco  United States  37.779259
# 25             Industrials      Arlington  United States  32.735582
# 26         Basic Materials     Pittsburgh  United States  40.441694
# 27             Industrials     Saint Paul  United States  44.949749
# 28              Healthcare  Thousand Oaks  United States  34.170561
# 29             Industrials         Irving  United States  32.829518
# 30                  Energy        Houston  United States  29.758938
# 31              Technology       San Jose  United States  37.336166
# 32      Consumer Defensive        Atlanta  United States  33.754466
# 33         Basic Materials        Midland  United States  31.836880
# 34  Communication Services        Burbank  United States  34.181209
#
#      Longitude
# 0   -97.678806
# 1  -122.419329
# 2  -121.955174
# 3   -73.407897
# 4  -122.419329
# 5   -73.712606
# 6  -112.074141
# 7  -121.890591
# 8  -121.974680
# 9     8.643352
# 10  -96.796856
# 11  -97.743700
# 12 -119.077936
# 13 -116.200886
# 14 -121.890591
# 15 -121.955174
# 16 -122.083210
# 17 -122.123877
# 18 -121.955174
# 19 -122.330062
# 20 -122.177992
# 21  -97.743700
# 22 -122.032290
# 23 -121.955174
# 24 -122.419329
# 25  -97.107119
# 26  -79.990086
# 27  -93.093103
# 28 -118.837594
# 29  -96.944218
# 30  -95.367697
# 31 -121.890591
# 32  -84.389815
# 33 -102.010377
# 34 -118.307201

# %% [markdown]
# ## Plot an interactive map

# %% [markdown]
# ### Map of company locations

# %%
# Plot the coordinates on a map using folium
# Initialize a map centered at a global level
company_map = folium.Map(location=[20, 0], zoom_start=2)

# Add a marker for each company
for index, row in df.iterrows():
    if pd.notna(row['Latitude']) and pd.notna(row['Longitude']):
        folium.Marker(
            location=[row['Latitude'], row['Longitude']],
            popup=f"{row['Ticker']} ({row['City']}, {row['Country']})",
            tooltip=row['Ticker']
        ).add_to(company_map)

# Save the map to an HTML file and display it
company_map.save("company_map.html")
company_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_969c0b350d385bf982069e3b8ca71d39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_969c0b350d385bf982069e3b8ca71d39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_969c0b350d385bf982069e3b8ca71d39 = L.map(
#                 &quot;map_969c0b350d385bf982069e3b8ca71d39&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77bb523748b85811b4a6341b708870a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77bb523748b85811b4a6341b708870a0.addTo(map_969c0b350d385bf982069e3b8ca71d39);
#
#
#             var marker_e4ac476b07e444188c2a85db0e643883 = L.marker(
#                 [30.5085915, -97.6788056],
#                 {
# }
#             ).addTo(map_969c0b350d385bf982069e3b8ca71d39);
#
#
#         var popup_d3b85190fc2f18e1320209863b1f7fe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22a5fa24cd5ebbd273efd8dad3ebd69e = $(`&lt;div id=&quot;html_22a5fa24cd5ebbd273efd8dad3ebd69e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELL (Round Rock, United States)&lt;/div&gt;`)[0];
#                 popup_d3b85190fc2f18e1320209863b1f7fe7.setContent(html_22a5fa24cd5ebbd273efd8dad3ebd69e);
#
#
#
#         marker_e4ac476b07e444188c2a85db0e643883.bindPopup(popup_d3b85190fc2f18e1320209863b1f7fe7)
#         ;
#
#
#
#
#             marker_e4ac476b07e444188c2a85db0e643883.bindTooltip(
#                 `&lt;div&gt;
#                      DELL
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_fa5a1a0f83940a3f16d36a961c31fde0 = L.marker(
#                 [37.7792588, -122.4193286],
#                 {
# }
#             ).addTo(map_969c0b350d385bf982069e3b8ca71d39);
#
#
#         var popup_0807b229de6ccfba06d7b46bf3af9905 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba6513beb6ff9ec5196da62a07a0f791 = $(`&lt;div id=&quot;html_ba6513beb6ff9ec5196da62a07a0f791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ABNB (San Francisco, United States)&lt;/div&gt;`)[0];
#                 popup_0807b229de6ccfba06d7b46bf3af9905.setContent(html_ba6513beb6ff9ec5196da62a07a0f791);
#
#
#
#         marker_fa5a1a0f83940a3f16d36a961c31fde0.bindPopup(popup_0807b229de6ccfba06d7b46bf3af9905)
#         ;
#
#
#
#
#             marker_fa5a1a0f83940a3f16d36a961c31fde0.bindTooltip(
#                 `&lt;div&gt;
#                      ABNB
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_78be41a608159b05c5b4353ff1530851 = L.marker(
#                 [37.3541132, -121.955174],
#                 {
# }
#             ).addTo(map_969c0b350d385bf982069e3b8ca71d39);
#
#
#         var popup_2da14349203ce8cbff500bb1cb44ef34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551ff8327b3d0b26293285c5157fcd96 = $(`&lt;div id=&quot;html_551ff8327b3d0b26293285c5157fcd96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANW (Santa Clara, United States)&lt;/div&gt;`)[0];
#                 popup_2da14349203ce8cbff500bb1cb44ef34.setContent(html_551ff8327b3d0b26293285c5157fcd96);
#
#
#
#         marker_78be41a608159b05c5b4353ff1530851.bindPopup(popup_2da14349203ce8cbff500bb1cb44ef34)
#         ;
#
#
#
#
#             marker_78be41a608159b05c5b4353ff1530851.bindTooltip(
#                 `&lt;div&gt;
#                      PANW
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_f6cfa8e386c7d1472013957c71817eea = L.marker(
#                 [41.1175966, -73.4078968],
#                 {
# }
#             ).addTo(map_969c0b350d385bf982069e3b8ca71d39);
#
#
#         var popup_5f37008e1714ff89cc9719efc2d598b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_248d0330fa1089a66c19808bc759c80e = $(`&lt;div id=&quot;html_248d0330fa1089a66c19808bc759c80e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BKNG (Norwalk, United States)&lt;/div&gt;`)[0];
#                 popup_5f37008e1714ff89cc9719efc2d598b9.setContent(html_248d0330fa1089a66c19808bc759c80e);
#
#
#
#         marker_f6cfa8e386c7d1472013957c71817eea.b

# %% [markdown]
# ### Map companies's market capitalization

# %%
# Normalize the market capitalization using Min-Max Scaling
scaler = MinMaxScaler(feature_range=(5, 50))  # Bubble size range between 5 and 50
df['Scaled Market Cap'] = scaler.fit_transform(df[['Market Cap']])

# Display the DataFrame
display(df)
# Out:
#    Ticker  Environment Score  Social Score  Governance Score     Market Cap  \
# 0    DELL               2.31          7.00              4.56    84432764928
# 1    ABNB               0.88          9.83              6.68    75800944640
# 2    PANW               0.05          7.99              4.89   130074296320
# 3    BKNG               0.87          9.55              4.02   178442420224
# 4    UBER               3.74         12.16              5.81   189752360960
# 5     IBM               1.58          6.68              5.01   231510409216
# 6    SCCO              11.89          7.76              5.91    83639222272
# 7    ADBE               2.78          6.75              4.71   148033077248
# 8    NFLX               0.16          7.38              8.35   528531456000
# 9     SAP                NaN           NaN               NaN   313430736896
# 10    TXN              10.42          4.79              4.92   170854121472
# 11   ORCL               1.58          6.49              6.57   653895598080
# 12    TTD               1.33         13.26              7.60    25459261440
# 13     MU               8.88          5.03              4.89   147020103680
# 14   PYPL               4.26         10.65              4.08    65214103552
# 15   INTC               7.56          6.86              4.39   107717304320
# 16   GOOG                NaN           NaN               NaN  2841723535360
# 17   MSFT               3.68          8.42              4.80  3775825444864
# 18   NVDA               2.81          3.64              5.65  4179408453632
# 19   AMZN               8.19         10.77              6.75  2477776175104
# 20   META               2.47         21.64              8.68  1890259828736
# 21   TSLA               3.04         14.13              7.60  1131616796672
# 22   AAPL               2.33          7.98              8.58  3557095374848
# 23    AMD               3.01          4.22              5.28   262560399360
# 24    CRM               4.06         10.33              4.09   238723514368
# 25     BA              11.22         20.69              6.53   173621444608
# 26     AA              14.95          8.90              3.55     8241264640
# 27    MMM              19.95         16.82              7.47    82834538496
# 28   AMGN               1.65         14.65              6.05   152700993536
# 29    CAT              10.17         11.77              6.39   198204096512
# 30    CVX              19.00          9.60              7.46   309597241344
# 31   CSCO               0.40          7.49              5.05   264469102592
# 32     KO              12.73         10.62              4.96   292477403136
# 33    DOW              14.65          4.08              3.63    17366679552
# 34    DIS               0.10          9.97              5.93   211993935872
#
#            Industry Sector           City        Country   Latitude  \
# 0               Technology     Round Rock  United States  30.508592
# 1        Consumer Cyclical  San Francisco  United States  37.779259
# 2               Technology    Santa Clara  United States  37.354113
# 3        Consumer Cyclical        Norwalk  United States  41.117597
# 4               Technology  San Francisco  United States  37.779259
# 5               Technology         Armonk  United States  41.132973
# 6          Basic Materials        Phoenix  United States  33.448437
# 7               Technology       San Jose  United States  37.336166
# 8   Communication Services      Los Gatos  United States  37.226611
# 9               Technology       Walldorf        Germany  49.303813
# 10              Technology         Dallas  United States  32.776272
# 11              Technology         Austin  United States  30.271129
# 12  Communication Services        Ventura  United States  34.445825
# 13              Technology          Boise  United States  43.616616
# 14      Financial Services       San Jose  United States  37.336166
# 15              Technology    Santa Clara  United States  37.354113
# 16  Communication Services  Mountain View  United States  37.389389
# 17              Technology        Redmond  United States  47.669414
# 18              Technology    Santa Clara  United States  37.354113
# 19       Consumer Cyclical        Seattle  United States  47.603832
# 20  Communication Services     Menlo Park  United States  37.451967
# 21       Consumer Cyclical         Austin  United States  30.271129
# 22              Technology      Cupertino  United States  37.322893
# 23              Technology    Santa Clara  United States  37.354113
# 24              Technology  San Francisco  United States  37.779259
# 25             Industrials      Arlington  United States  32.735582
# 26         Basic Materials     Pittsburgh  United States  40.441694
# 27             Industrials     Saint Paul  United States  44.949749
# 28              Healthcare  Thousand Oaks  United States  34.170561
# 29             Industrials         Irving  United States  32.829518
# 30                  Energy        Houston  United States  29.758938
# 31              Technology       San Jose  United States  37.336166
# 32      Consumer Defensive        Atlanta  United States  33.754466
# 33         Basic Materials        Midland  United States  31.836880
# 34  Communication Services        Burbank  United States  34.181209
#
#      Longitude  Scaled Market Cap
# 0   -97.678806           5.821980
# 1  -122.419329           5.728857
# 2  -121.955174           6.314377
# 3   -73.407897           6.836189
# 4  -122.419329           6.958205
# 5   -73.712606           7.408705
# 6  -112.074141           5.813419
# 7  -121.890591           6.508123
# 8  -121.974680          10.613071
# 9     8.643352           8.292490
# 10  -96.796856           6.754324
# 11  -97.743700          11.965543
# 12 -119.077936           5.185754
# 13 -116.200886           6.497194
# 14 -121.890591           5.614643
# 15 -121.955174           6.073182
# 16 -122.083210          35.568591
# 17 -122.123877          45.646006
# 18 -121.955174          50.000000
# 19 -122.330062          31.642200
# 20 -122.177992          25.303870
# 21  -97.743700          17.119365
# 22 -122.032290          43.286270
# 23 -121.955174           7.743683
# 24 -122.419329           7.486523
# 25  -97.107119           6.784179
# 26  -79.990086           5.000000
# 27  -93.093103           5.804738
# 28 -118.837594           6.558482
# 29  -96.944218           7.049385
# 30  -95.367697           8.251133
# 31 -121.890591           7.764275
# 32  -84.389815           8.066438
# 33 -102.010377           5.098448
# 34 -118.307201           7.198155

# %%
# Initialize a map centered globally
company_map = folium.Map(location=[20, 0], zoom_start=2)

# Add a marker with bubbles scaled by market capitalization
for index, row in df.iterrows():
    if pd.notna(row['Latitude']) and pd.notna(row['Market Cap']):
        folium.CircleMarker(
            location=[row['Latitude'], row['Longitude']],
            radius=row['Scaled Market Cap'],  # Scaled bubble size
            color='blue',
            fill=True,
            fill_opacity=0.5,  # Adjust transparency as needed
            popup=folium.Popup(f"{row['Ticker']} - Market Cap: ${row['Market Cap']:,}")
        ).add_to(company_map)

# Save the map to an HTML file and display it
company_map.save("company_map_market_cap.html")
company_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e019d98938c004631b9e54f5dd5a5ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e019d98938c004631b9e54f5dd5a5ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e019d98938c004631b9e54f5dd5a5ff = L.map(
#                 &quot;map_1e019d98938c004631b9e54f5dd5a5ff&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_793995b753d44927892b53437fe12d87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_793995b753d44927892b53437fe12d87.addTo(map_1e019d98938c004631b9e54f5dd5a5ff);
#
#
#             var circle_marker_0b443fafaa57653a1136f2e52b369278 = L.circleMarker(
#                 [30.5085915, -97.6788056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.82198036127834, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e019d98938c004631b9e54f5dd5a5ff);
#
#
#         var popup_94f97e5b035e54e62651cfde0f2266bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71cb468f0eeefcfaa487451b52c0892f = $(`&lt;div id=&quot;html_71cb468f0eeefcfaa487451b52c0892f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELL - Market Cap: $84,432,764,928&lt;/div&gt;`)[0];
#                 popup_94f97e5b035e54e62651cfde0f2266bf.setContent(html_71cb468f0eeefcfaa487451b52c0892f);
#
#
#
#         circle_marker_0b443fafaa57653a1136f2e52b369278.bindPopup(popup_94f97e5b035e54e62651cfde0f2266bf)
#         ;
#
#
#
#
#             var circle_marker_0b6c5712c03e1de42e6461be7b6a3597 = L.circleMarker(
#                 [37.7792588, -122.4193286],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5.728857286762147, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e019d98938c004631b9e54f5dd5a5ff);
#
#
#         var popup_5c57b0f37ab2f502dc422ab95a5ccd0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_064262a5c0b8f276268213363bd78c17 = $(`&lt;div id=&quot;html_064262a5c0b8f276268213363bd78c17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ABNB - Market Cap: $75,800,944,640&lt;/div&gt;`)[0];
#                 popup_5c57b0f37ab2f502dc422ab95a5ccd0c.setContent(html_064262a5c0b8f276268213363bd78c17);
#
#
#
#         circle_marker_0b6c5712c03e1de42e6461be7b6a3597.bindPopup(popup_5c57b0f37ab2f502dc422ab95a5ccd0c)
#         ;
#
#
#
#
#             var circle_marker_fb63e6157413a2aad4a9cf476c68802f = L.circleMarker(
#                 [37.3541132, -121.955174],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 6.314377050162042, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_1e019d98938c004631b9e54f5dd5a5ff);
#
#
#         var popup_5966adabe24e9ef9577656a5534e6ce1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c91d8515de40b389e1121f0414196cb = $(`&lt;div id=&quot;html_0c91d8515de40b389e1121f0414196cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANW - Market Cap: $130,074,296,320&lt;/div&gt;`)[0];
#                 popup_5966adabe24e9ef9577656a5534e6ce1.setContent(html_0c91d8515de40b389e1121f0414196cb);
#
#
#
#         circle_marker_fb63e6157413a2aad4a9cf476c68802f.bindPopup(popup_5966adabe24e9ef9577656a5534e6ce1

# %% [markdown]
# ### Map companies' ESG risk profiles

# %%
# Initialize a map centered globally
company_map = folium.Map(location=[20, 0], zoom_start=2)

# Add layers for Environmental, Social, and Governance Scores
esg_layers = {
    'Environment Score': folium.FeatureGroup(name='Environment Score', overlay=True),
    'Social Score': folium.FeatureGroup(name='Social Score', overlay=True),
    'Governance Score': folium.FeatureGroup(name='Governance Score', overlay=True)
}

# Function to add circle marker based on ESG score
def add_esg_layer(esg_layer, score_column, color, popup_label):
    for index, row in df.iterrows():
        if pd.notna(row['Latitude']) and pd.notna(row[score_column]):
            folium.CircleMarker(
                location=[row['Latitude'], row['Longitude']],
                radius=row[score_column] / 0.5,  # Adjust the size of the bubbles
                color=color,
                fill=True,
                fill_opacity=0.4, # Adjust transparency for the fill (0 = fully transparent, 1 = fully opaque)
                opacity=0.2,  # Adjust transparency for the circle's border (0 = fully transparent, 1 = fully opaque)
                popup=folium.Popup(f"{row['Ticker']} - {popup_label}: {row[score_column]}")
            ).add_to(esg_layer)

# Add circle markers for each ESG score
add_esg_layer(esg_layers['Environment Score'], 'Environment Score', 'green', 'Environment Score')
add_esg_layer(esg_layers['Social Score'], 'Social Score', 'blue', 'Social Score')
add_esg_layer(esg_layers['Governance Score'], 'Governance Score', 'red', 'Governance Score')

# Add the layers to the map
for layer in esg_layers.values():
    layer.add_to(company_map)

# Add layer control to toggle between the ESG layers
folium.LayerControl().add_to(company_map)

# Save the map to an HTML file and display it
company_map.save("company_map_esg.html")
company_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27bca8241564abbaa7fbf6922eb27dd1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27bca8241564abbaa7fbf6922eb27dd1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27bca8241564abbaa7fbf6922eb27dd1 = L.map(
#                 &quot;map_27bca8241564abbaa7fbf6922eb27dd1&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4050ae796e90dc593afdf61a6c9be11 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4050ae796e90dc593afdf61a6c9be11.addTo(map_27bca8241564abbaa7fbf6922eb27dd1);
#
#
#             var feature_group_5203e1d9dff4d7b7daa84166a58c0844 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_9b38349afbebc1bf9e1e3602079ece90 = L.circleMarker(
#                 [30.5085915, -97.6788056],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 4.62, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5203e1d9dff4d7b7daa84166a58c0844);
#
#
#         var popup_1bb17c8e700cf0182f0b378c0d575c53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26d49e21033e293c45da5b5982c10cc1 = $(`&lt;div id=&quot;html_26d49e21033e293c45da5b5982c10cc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;DELL - Environment Score: 2.31&lt;/div&gt;`)[0];
#                 popup_1bb17c8e700cf0182f0b378c0d575c53.setContent(html_26d49e21033e293c45da5b5982c10cc1);
#
#
#
#         circle_marker_9b38349afbebc1bf9e1e3602079ece90.bindPopup(popup_1bb17c8e700cf0182f0b378c0d575c53)
#         ;
#
#
#
#
#             var circle_marker_43374a088feee814b460a0e34e022efa = L.circleMarker(
#                 [37.7792588, -122.4193286],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 1.76, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5203e1d9dff4d7b7daa84166a58c0844);
#
#
#         var popup_ad40bc46aff9311e4285a2c5bdba9f24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7d7bc6b96a23352b8ff6b788701cbe5 = $(`&lt;div id=&quot;html_d7d7bc6b96a23352b8ff6b788701cbe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;ABNB - Environment Score: 0.88&lt;/div&gt;`)[0];
#                 popup_ad40bc46aff9311e4285a2c5bdba9f24.setContent(html_d7d7bc6b96a23352b8ff6b788701cbe5);
#
#
#
#         circle_marker_43374a088feee814b460a0e34e022efa.bindPopup(popup_ad40bc46aff9311e4285a2c5bdba9f24)
#         ;
#
#
#
#
#             var circle_marker_9968bd2508cf1e54e95237fc49027329 = L.circleMarker(
#                 [37.3541132, -121.955174],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.4, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.2, &quot;radius&quot;: 0.1, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_5203e1d9dff4d7b7daa84166a58c0844);
#
#
#         var popup_0695da76809cbdf192be944cacbbdf2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3bb0345c80ac3dd93dbce1b1128627d = $(`&lt;div id=&quot;html_f3bb0345c80ac3dd93dbce1b1128627d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;PANW - Environment Score: 0.05&lt;/div&gt;`)[0];
#                 popup_0695da76809cbdf192be944cacbbdf2a.setContent(html_f3bb0345c80ac3dd93dbce1b1128627d);
